# %%
import ollama

model = "llama3:8b"

def ask_llm(inp):

    rules = """
    You are a professional Financial Assistant.

    Responsibilities:
    - Help users create budgets and savings plans.
    - Explain financial concepts in simple language.
    - Provide investment education.
    - Assist with debt repayment strategies.
    - Help calculate interest, EMI, returns, and expenses.
    - Suggest ways to reduce spending and improve savings habits.

    Rules:
    - Never claim to be a licensed financial advisor.
    - Do not guarantee profits or returns.
    - Mention risks associated with investments.
    - Avoid legal and tax advice.
    - Keep responses simple and practical.
    """

    response = ollama.chat(
        model=model,
        messages=[
            {
                "role": "system",
                "content": rules
            },
            {
                "role": "user",
                "content": inp
            }
        ],
        stream=True
    )

    for res in response:
        print(res["message"]["content"], end="", flush=True)

    print("\n")


while True:
    inp = input("Enter your financial question: ")

    if inp.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    ask_llm(inp)

# %%
from langchain_community.document_loaders import PyPDFLoader

FILE_PATH = r"C:\Users\admin\Downloads\Bhagyasri_Cover_Letter.pdf"

loader = PyPDFLoader(FILE_PATH)
docs = loader.load()

print(docs[0].page_content)
# Out:
# Bhagyasri Andhavarapu
# Guntur, Andhra Pradesh
# Email: your.email@example.com
# Phone: +91 XXXXXXXXXX
# Date: 11 June 2026
# Subject: Application for Software Engineer Intern / Fresher Position
# Dear Hiring Manager,
# I am writing to express my interest in the Software Engineer Intern/Fresher position at your
# esteemed organization. I am currently pursuing a Bachelor of Technology in Information
# Technology and am eager to apply my technical knowledge and problem-solving skills in a
# professional environment.
# Throughout my academic journey, I have developed a strong foundation in Java, Python, SQL,
# HTML, CSS, and JavaScript. During my internship at CodSoft, I worked on projects such as a
# Number Game, Student Grade Calculator, and ATM Machine Simulation, which strengthened my
# programming and analytical skills.
# Additionally, I have completed certifications in Java Programming through NPTEL and Python
# Programming through InfySkill. These experiences have enhanced my understanding of software
# development principles and reinforced my passion for continuous learning.
# I am enthusiastic about contributing to your organization and believe that my dedication,
# adaptability, and eagerness to learn will allow me to make meaningful contributions to your team.
# Thank you for considering my application. I would welcome the opportunity to discuss how my skills
# and experiences align with your requirements. I look forward to hearing from you.
# Yours sincerely,
# Bhagyasri Andhavarapu

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=60
)
texts = text_splitter.split_documents(docs)

# %%
print(texts[0])
print(texts[1])
# Out:
# page_content='Bhagyasri Andhavarapu
# Guntur, Andhra Pradesh
# Email: your.email@example.com
# Phone: +91 XXXXXXXXXX
# Date: 11 June 2026
# Subject: Application for Software Engineer Intern / Fresher Position
# Dear Hiring Manager,
# I am writing to express my interest in the Software Engineer Intern/Fresher position at your' metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-11T06:06:42+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-06-11T06:06:42+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'C:\\Users\\admin\\Downloads\\Bhagyasri_Cover_Letter.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}
# page_content='esteemed organization. I am currently pursuing a Bachelor of Technology in Information
# Technology and am eager to apply my technical knowledge and problem-solving skills in a
# professional environment.
# Throughout my academic journey, I have developed a strong foundation in Java, Python, SQL,' metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-11T06:06:42+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-06-11T06:06:42+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'C:\\Users\\admin\\Downloads\\Bhagyasri_Cover_Letter.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
model="BAAI/bge-large-en-v1.5"

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings= HuggingFaceEmbeddings(model_name="BAAI/bge-large-en-v1.5")
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
from langchain_chroma import Chroma
vector_store = Chroma(
    collection_name = "sample_RAG",
    embedding_function=embeddings,
persist_directory = "./chroma_langchain_db",
)

# %%
vector_store._collection.count()
# Out:
# 0

# %%
from langchain_community.vectorstores.utils import filter_complex_metadata
texts = filter_complex_metadata(texts)

# %%
texts[0]
# Out:
# Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-11T06:06:42+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-06-11T06:06:42+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'C:\\Users\\admin\\Downloads\\Bhagyasri_Cover_Letter.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Bhagyasri Andhavarapu\nGuntur, Andhra Pradesh\nEmail: your.email@example.com\nPhone: +91 XXXXXXXXXX\nDate: 11 June 2026\nSubject: Application for Software Engineer Intern / Fresher Position\nDear Hiring Manager,\nI am writing to express my interest in the Software Engineer Intern/Fresher position at your')

# %%
vector_store.add_documents(texts)
# Out:
# ['5ec76abf-e32c-4da4-8a72-ff96d49ceffe',
#  'a95772db-a95a-4843-ae5a-5723a7139f55',
#  '46542e1f-3c9c-449f-a820-6ffbbcabf67a',
#  'b57a09fd-d7e0-46b7-8dbb-afc1dc78f4c6',
#  'd68250cf-c5b4-4d6c-a9d3-cca3bb883115',
#  '98d34dcc-e7d2-4af7-804c-bfba218c40cb']

# %%
vector_store._collection.count()
# Out:
# 6

# %%
vector_store._collection.get(ids = ['da60798f-2f26-42dd-823b-eef487a821f7'], include = ["embeddings","documents"])
# Out:
# {'ids': [],
#  'embeddings': array([], dtype=float64),
#  'documents': [],
#  'uris': None,
#  'included': ['embeddings', 'documents'],
#  'data': None,
#  'metadatas': None}
